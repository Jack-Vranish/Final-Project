# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://data.wprdc.org/dataset/307d923c-418e-4838-b2b9-d0896d483f33/resource/74deca7d-b398-4137-83d7-553a7162f464/download/household-type-including-living-alone.csv")

# %%
#Highest numbers here are some of the best neighborhoods to have a dog, as more households that contain families are more likely to be pet friendly
graph = data.plot(kind = "bar", x='Neighborhood', y='Estimate; Family households:', figsize=(13, 5))
plt.show()

# %%
#Highest numbers here are some of the worst neighborhoods to have a dog as single households that do not contain families are less likely to be pet friendly
graph2 = data.plot(kind = "bar", x='Neighborhood', y='Estimate; Nonfamily households:', figsize=(13, 5))
plt.show()

# %% [markdown]
# For my dataset, I used one that gave a list of the neighborhoods in Pittsburgh and it listed how many single and family households there were in each of the neighborhoods. For my metric, I decided that the more family households there were, the freindler the neighborhood would be to having a dog around their area, as families are more common to having a dog. I then visualized the data into a bar graph, and with the first bar graph that I created, I was able to determine that my top ranking neighborhoods included Brighton Heights, Carrick, and then Squirrel Hill South being the highest ranking one. I also included a bonus throwaway graph that showed some of the "worst" metrics that could be included in my scores, with the more single housing neighborhoods being "less" pet friendly. So by my metrics, Shadyside was the worst.
