# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("https://pghgishub-pittsburghpa.opendata.arcgis.com/datasets/3ca13246362540fa8b4b567f84a1255b_0.csv?outSR=%7B%22latestWkid%22%3A6565%2C%22wkid%22%3A103142%7D")

# %%
data.head()
# Out:
#    OBJECTID  Neighborhood_2010_FID_BlockG  Neighborhood_2010_STATEFP10  \
# 0         1                             0                           42
# 1         2                             1                           42
# 2         3                             2                           42
# 3         4                             3                           42
# 4         5                             5                           42
#
#    Neighborhood_2010_COUNTYFP10  Neighborhood_2010_TRACTCE10  \
# 0                             3                        40500
# 1                             3                        40400
# 2                             3                        40200
# 3                             3                        30500
# 4                             3                        20300
#
#    Neighborhood_2010_BLKGRPCE10  Neighborhood_2010_GEOID10  \
# 0                             1               420030405001
# 1                             1               420030404001
# 2                             2               420030402002
# 3                             2               420030305002
# 4                             1               420030203001
#
#   Neighborhood_2010_NAMELSAD10 Neighborhood_2010_MTFCC10  \
# 0                Block Group 1                     G5030
# 1                Block Group 1                     G5030
# 2                Block Group 2                     G5030
# 3                Block Group 2                     G5030
# 4                Block Group 1                     G5030
#
#   Neighborhood_2010_FUNCSTAT10  ...  SNAP_All_csv_Commute_to_Work__C  \
# 0                            S  ...                             6.9%
# 1                            S  ...                             7.2%
# 2                            S  ...                             1.0%
# 3                            S  ...                             9.6%
# 4                            S  ...                            19.1%
#
#    SNAP_All_csv_Commute_to_Work__P  SNAP_All_csv_Commute_to_Work__T  \
# 0                            13.3%                             0.0%
# 1                            11.5%                             0.4%
# 2                            22.1%                             0.0%
# 3                            16.5%                             2.0%
# 4                            18.1%                             0.0%
#
#    SNAP_All_csv_Commute_to_Work__M  SNAP_All_csv_Commute_to_Work__B  \
# 0                             0.0%                             0.0%
# 1                             0.0%                             2.9%
# 2                             0.0%                             0.0%
# 3                             0.0%                             0.0%
# 4                             0.0%                             0.0%
#
#    SNAP_All_csv_Commute_to_Work__W  SNAP_All_csv_Commute_to_Work__O  \
# 0                            62.4%                             0.0%
# 1                            52.6%                             0.4%
# 2                            40.8%                             0.7%
# 3                             6.5%                             0.0%
# 4                             0.0%                             0.0%
#
#    SNAP_All_csv_Work_at_Home__2010  SHAPE_Length    SHAPE_Area
# 0                             1.2%  11525.904546 -7.842997e+06
# 1                             4.4%  20945.562570 -1.390469e+07
# 2                             0.0%  18280.484515 -5.998649e+06
# 3                             0.0%  15694.771444 -7.203631e+06
# 4                             9.0%  24019.532672 -1.694875e+07
#
# [5 rows x 192 columns]
